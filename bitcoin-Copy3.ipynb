# %% [markdown]
# Importing the libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('coin_Bitcoin.csv')
df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %% [markdown]
#  Data Cleaning

# %%
#To improve clarity of viewing the numbers let's round them up to 3 decimals
pd.set_option('display.float_format',lambda x : '%.3f' % x)
df['Date']=df['Date'].str.split(' ').str[0]
df
# Out:
#        SNo     Name Symbol        Date      High       Low      Open  \
# 0        1  Bitcoin    BTC  2013-04-29   147.488   134.000   134.444
# 1        2  Bitcoin    BTC  2013-04-30   146.930   134.050   144.000
# 2        3  Bitcoin    BTC  2013-05-01   139.890   107.720   139.000
# 3        4  Bitcoin    BTC  2013-05-02   125.600    92.282   116.380
# 4        5  Bitcoin    BTC  2013-05-03   108.128    79.100   106.250
# ...    ...      ...    ...         ...       ...       ...       ...
# 2986  2987  Bitcoin    BTC  2021-07-02 33939.589 32770.681 33549.600
# 2987  2988  Bitcoin    BTC  2021-07-03 34909.260 33402.697 33854.421
# 2988  2989  Bitcoin    BTC  2021-07-04 35937.567 34396.477 34665.565
# 2989  2990  Bitcoin    BTC  2021-07-05 35284.344 33213.661 35284.344
# 2990  2991  Bitcoin    BTC  2021-07-06 35038.536 33599.916 33723.510
#
#          Close          Volume        Marketcap
# 0      144.540           0.000   1603768864.500
# 1      139.000           0.000   1542813125.000
# 2      116.990           0.000   1298954593.750
# 3      105.210           0.000   1168517495.250
# 4       97.750           0.000   1085995168.750
# ...        ...             ...              ...
# 2986 33897.049 38728974942.250 635450784106.090
# 2987 34668.548 24383958643.260 649939701346.230
# 2988 35287.780 24924307911.110 661574836314.860
# 2989 33746.002 26721554282.070 632696207199.700
# 2990 34235.193 26501259869.760 641899161593.760
#
# [2991 rows x 10 columns]

# %%
df.set_index('SNo', inplace=True) #Setting the index Column
df
# Out:
#          Name Symbol        Date      High       Low      Open     Close  \
# SNo
# 1     Bitcoin    BTC  2013-04-29   147.488   134.000   134.444   144.540
# 2     Bitcoin    BTC  2013-04-30   146.930   134.050   144.000   139.000
# 3     Bitcoin    BTC  2013-05-01   139.890   107.720   139.000   116.990
# 4     Bitcoin    BTC  2013-05-02   125.600    92.282   116.380   105.210
# 5     Bitcoin    BTC  2013-05-03   108.128    79.100   106.250    97.750
# ...       ...    ...         ...       ...       ...       ...       ...
# 2987  Bitcoin    BTC  2021-07-02 33939.589 32770.681 33549.600 33897.049
# 2988  Bitcoin    BTC  2021-07-03 34909.260 33402.697 33854.421 34668.548
# 2989  Bitcoin    BTC  2021-07-04 35937.567 34396.477 34665.565 35287.780
# 2990  Bitcoin    BTC  2021-07-05 35284.344 33213.661 35284.344 33746.002
# 2991  Bitcoin    BTC  2021-07-06 35038.536 33599.916 33723.510 34235.193
#
#               Volume        Marketcap
# SNo
# 1              0.000   1603768864.500
# 2              0.000   1542813125.000
# 3              0.000   1298954593.750
# 4              0.000   1168517495.250
# 5              0.000   1085995168.750
# ...              ...              ...
# 2987 38728974942.250 635450784106.090
# 2988 24383958643.260 649939701346.230
# 2989 24924307911.110 661574836314.860
# 2990 26721554282.070 632696207199.700
# 2991 26501259869.760 641899161593.760
#
# [2991 rows x 9 columns]

# %%
 #let's check the number of rows and columns in our data
df.shape
# Out:
# (2991, 9)

# %%
#Let's check null values and data types in the data
df.info()
# No null value found but the column 'Date' is in the wrong data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2991 entries, 1 to 2991
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       2991 non-null   object
#  1   Symbol     2991 non-null   object
#  2   Date       2991 non-null   object
#  3   High       2991 non-null   float64
#  4   Low        2991 non-null   float64
#  5   Open       2991 non-null   float64
#  6   Close      2991 non-null   float64
#  7   Volume     2991 non-null   float64
#  8   Marketcap  2991 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 233.7+ KB

# %%
# Let's change the data type of 'Date' column to datetime 
df['Date']=pd.to_datetime(df['Date'])
df.dtypes
#Date column has changed to datetime64 data type
# Out:
# Name                 object
# Symbol               object
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Marketcap           float64
# dtype: object

# %%
df.isnull().sum() #No null values found! Great!
# Out:
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
#Let's check for duplicate values in our data
df.duplicated()
# No duplicate values found!
# Out:
# SNo
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 2987    False
# 2988    False
# 2989    False
# 2990    False
# 2991    False
# Length: 2991, dtype: bool

# %%
# Now let's drop unnecssary columns to improve clarity
df.drop(columns=['Symbol','Name'],inplace=True)

# %%
df
# Out:
#            Date      High       Low      Open     Close          Volume  \
# SNo
# 1    2013-04-29   147.488   134.000   134.444   144.540           0.000
# 2    2013-04-30   146.930   134.050   144.000   139.000           0.000
# 3    2013-05-01   139.890   107.720   139.000   116.990           0.000
# 4    2013-05-02   125.600    92.282   116.380   105.210           0.000
# 5    2013-05-03   108.128    79.100   106.250    97.750           0.000
# ...         ...       ...       ...       ...       ...             ...
# 2987 2021-07-02 33939.589 32770.681 33549.600 33897.049 38728974942.250
# 2988 2021-07-03 34909.260 33402.697 33854.421 34668.548 24383958643.260
# 2989 2021-07-04 35937.567 34396.477 34665.565 35287.780 24924307911.110
# 2990 2021-07-05 35284.344 33213.661 35284.344 33746.002 26721554282.070
# 2991 2021-07-06 35038.536 33599.916 33723.510 34235.193 26501259869.760
#
#             Marketcap
# SNo
# 1      1603768864.500
# 2      1542813125.000
# 3      1298954593.750
# 4      1168517495.250
# 5      1085995168.750
# ...               ...
# 2987 635450784106.090
# 2988 649939701346.230
# 2989 661574836314.860
# 2990 632696207199.700
# 2991 641899161593.760
#
# [2991 rows x 7 columns]

# %% [markdown]
# Exploratory Data Analysis

# %%
#Let's explor some statistical information from the data
df.select_dtypes(include='number').describe().transpose()
# Out:
#              count             mean              std           min  \
# High      2991.000         6893.326        11642.832        74.561
# Low       2991.000         6486.010        10869.032        65.526
# Open      2991.000         6700.146        11288.044        68.505
# Close     2991.000         6711.290        11298.142        68.431
# Volume    2991.000  10906334004.867  18888952979.843         0.000
# Marketcap 2991.000 120876059112.884 210943836987.405 778411178.875
#
#                      25%             50%              75%               max
# High             436.179        2387.610         8733.927         64863.099
# Low              422.879        2178.500         8289.800         62208.964
# Open             430.445        2269.890         8569.656         63523.755
# Close            430.569        2286.410         8576.239         63503.458
# Volume      30367250.000   946035968.000  15920149610.469  350967941479.060
# Marketcap 6305579328.825 37415031060.800 149995739945.595 1186364044140.270

# %%
#Market capitalization went from around 778 million$ to 1.186 trillion$!
# Lowest closing price of 68.431$ reached its peak at 63503.458$

# %%
#Let's start by finding correlation among the columns
df.corr(numeric_only=True)
# Out:
#            High   Low  Open  Close  Volume  Marketcap
# High      1.000 0.999 0.999  0.999   0.810      0.999
# Low       0.999 1.000 0.999  0.999   0.803      0.999
# Open      0.999 0.999 1.000  0.999   0.808      0.998
# Close     0.999 0.999 0.999  1.000   0.807      1.000
# Volume    0.810 0.803 0.808  0.807   1.000      0.809
# Marketcap 0.999 0.999 0.998  1.000   0.809      1.000

# %%
#plotting a heatmap would provide better visual information
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.rcParams['figure.figsize']=(8,6)
plt.show()

# %%
#It appears that Volume sold has strong and equal correlation of 0.81 with 'High', 'Close','Open' and 'Low' columns

# %%
#Let's make a Pairplot to visually explore the relations
plt.style.use('default')
plt.figure(figsize=(10,10))
sns.pairplot(df)
plt.show()
# Out:
# E:\Anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Graphs with upward slope indicates stong relation between two variables.

# %%
#Let's see the start data and end date in the given data as it will be used for next graphs
df['Date'].min(),df['Date'].max()
# Out:
# (Timestamp('2013-04-29 00:00:00'), Timestamp('2021-07-06 00:00:00'))

# %%
#So, the date starts from April 29th, 2013 and ends at July 6th, 2021.

# %%
#Now let's see the change of Closing price of bitcoin by year

# %%
plt.style.use('default')
plt.figure(figsize=(8,6))
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(df['Date'],df['Close'])
plt.title('Close Price of bitcoin by year')
plt.show()

# %%
# What does the average price of bitcoin look like over the past years?
plt.style.use('default')
average_close = df.resample('Y', on='Date')['Close'].mean()
# Plot the yearly average price of Bitcoin
plt.figure(figsize=(10, 6))
plt.plot(average_close.index, average_close.values, marker='o', color='blue',mfc='g')
plt.title('Yearly Average Price of Bitcoin')
plt.xlabel('Year')
plt.ylabel('Average Close Price')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
#Also, let's see the change of Market capitalizaion of bitcoin by year

# %%
plt.style.use('default')
plt.figure(figsize=(8,6))
plt.xlabel('Date')
plt.ylabel('Marketcap')
plt.plot(df['Date'],df['Marketcap'])
plt.title('Market capitalization of bitcoin by year')
plt.show()

# %%
# Now we want to see the highest,lowest and average closing prices for each year to find any patterns in the change.

# %%
highest_close=df.resample('Y', on='Date')['Close'].max() #to extract the years from the 'Date' column
highest_close
# Out:
# Date
# 2013-12-31    1151.170
# 2014-12-31     953.290
# 2015-12-31     465.321
# 2016-12-31     975.921
# 2017-12-31   19497.400
# 2018-12-31   17527.000
# 2019-12-31   13016.232
# 2020-12-31   29001.720
# 2021-12-31   63503.458
# Freq: A-DEC, Name: Close, dtype: float64

# %%
lowest_close= df.resample('Y', on='Date')['Close'].min()
lowest_close
# Out:
# Date
# 2013-12-31      68.431
# 2014-12-31     310.737
# 2015-12-31     178.103
# 2016-12-31     364.331
# 2017-12-31     777.757
# 2018-12-31    3236.762
# 2019-12-31    3399.472
# 2020-12-31    4970.788
# 2021-12-31   29374.152
# Freq: A-DEC, Name: Close, dtype: float64

# %%
average_close= df.resample('Y', on='Date')['Close'].mean()
average_close
# Out:
# Date
# 2013-12-31     257.974
# 2014-12-31     527.236
# 2015-12-31     272.453
# 2016-12-31     568.492
# 2017-12-31    4006.034
# 2018-12-31    7572.299
# 2019-12-31    7395.246
# 2020-12-31   11116.378
# 2021-12-31   45539.276
# Freq: A-DEC, Name: Close, dtype: float64

# %%
#Plotting the above prices together to visualize all these numeric information

# %%
plt.style.use('default')
plt.figure(figsize=(10, 6))
plt.plot(highest_close.index.year, highest_close.values, label='Highest Closing Price', marker='o')
plt.plot(lowest_close.index.year, lowest_close.values, label='Lowest Closing Price', marker='o')
plt.plot(average_close.index.year, average_close.values, label='average Closing Price', marker='o')
plt.title('Bitcoin Highest and Lowest Closing Prices by Year')
plt.xlabel('Year')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#upward trend since 2016 but downward from 2017 to 2019. reached peak in 2021

# %%
#Let's see it for trading volume of bitcoins

# %%
highest_volume = df.resample('Y', on='Date')['Volume'].max()
lowest_volume = df.resample('Y', on='Date')['Volume'].min()

# %%
highest_volume, lowest_volume
# Out:
# (Date
#  2013-12-31       46862700.000
#  2014-12-31      126314000.000
#  2015-12-31      263900000.000
#  2016-12-31      363320992.000
#  2017-12-31    22197999616.000
#  2018-12-31    23840899072.000
#  2019-12-31    45105733173.189
#  2020-12-31    74156772074.960
#  2021-12-31   350967941479.060
#  Freq: A-DEC, Name: Volume, dtype: float64,
#  Date
#  2013-12-31             0.000
#  2014-12-31       2857830.000
#  2015-12-31       7860650.000
#  2016-12-31      28514000.000
#  2017-12-31      60851700.000
#  2018-12-31    2923670016.000
#  2019-12-31    4324200990.195
#  2020-12-31   12252601474.785
#  2021-12-31   24383958643.260
#  Freq: A-DEC, Name: Volume, dtype: float64)

# %%
plt.style.use('default')
plt.figure(figsize=(10, 6))
plt.plot(highest_volume.index.year, highest_volume.values, label='Highest Volume', marker='o')
plt.plot(lowest_volume.index.year, lowest_volume.values, label='Lowest Volume', marker='o')
plt.title('Highest and Lowest volume of bitcoin sold by Year')
plt.xlabel('Year')
plt.ylabel('Volume')
plt.legend()
plt.grid(True)
plt.show()

# %%
#the highest and lowest volume has always been upward since 2018

# %%
#Now, let's have a closer look at the last 12 month's data
# To improve smoothness of curve ,30day rolling window will be used

# %%
last_12_months = df[df['Date'] >= df['Date'].max() - pd.DateOffset(months=12)]
# rolling statistics for the last 12 months
rolling_stats = last_12_months.rolling(window='30D', on='Date').mean()

# %%
plt.figure(figsize=(10, 6))
plt.plot(last_12_months['Date'], last_12_months['Close'], label='Close Price')
plt.plot(rolling_stats['Date'], rolling_stats['Close'], label='Rolling 30-Day Average Close Price', color='red')
plt.title('Rolling 30-Day Average Close Price for Last 12 Months')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Let's explore average price changes over the last 12 months of the data

# %%
last_12_months.loc[:, 'Month'] = last_12_months['Date'].dt.month
average_prices = last_12_months.groupby('Month')[['Close', 'Open', 'High']].mean()
plt.figure(figsize=(10, 6))
average_prices.plot(marker='o')
plt.title('Average Close, Open, and High Prices of Last 12 Months')
plt.xlabel('Month')
plt.ylabel('Price')
plt.xticks(range(1, 13), ['Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul'])
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\rn2\AppData\Local\Temp\ipykernel_12160\3040800621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_12_months.loc[:, 'Month'] = last_12_months['Date'].dt.month

# %%
#Now, let's see the percentage change in close price over the last 12 months

# %%
percentage_change = last_12_months['Close'].pct_change()
plt.figure(figsize=(10, 6))
plt.plot(last_12_months['Date'],percentage_change)
plt.title('Percentage Change in Close Price (Last 12 Months)')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.grid(True)
plt.show()

# %%
#Again, making a rolling window of 15 days to improve readablity

# %%
rolling_mean = percentage_change.rolling(window=15).mean()  # Adjusting window size to 15days
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(last_12_months['Date'], rolling_mean)
plt.title('Rolling Window of Change in Close Price Over Last 12 Months')
plt.xlabel('Date')
plt.ylabel('Percentage Change (Rolling Mean)')
plt.grid(True)
plt.show()

# %%
#Let's see a distribution plot of Volume sold over last 12 months
Volume_mill= last_12_months['Volume'] / 1000000 #to convert in millions unit
plt.figure(figsize=(10, 6))
sns.histplot(Volume_mill, kde=True, color='blue')
plt.title('Distribution of Volume sold Over Last 12 Months')
plt.xlabel('Volume(millions)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# The distribution is right-skewed where most of ther values are around 50000 millions.
